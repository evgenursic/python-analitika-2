# %% [markdown]
# # Del 3: Pandas - Data Cleaning napredno - Vaje

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dataset podatki
#
# - **name**: Recipe name (string)
# - **id**: Original recipe ID
# - **contributor_id**: ID of the user who submitted this recipe
# - **submitted**: When this recipe was submitted to Food.com
# - **tags**: Food.com tags for a recipe
# - **nutrition**: Values in order (PDV except for calories): calories, total fat, sugar, sodium, protein, saturated fat, carbohydrates
# - **n_steps**: Number of recipe steps
# - **steps**: Recipe steps, in order
# - **description**: Recipe description
# - **ingredients**: Recipe ingredient names
# - **n_ingredients**: Number of ingredients in the recipe

# %%
recipes = pd.read_csv("data/recipes.csv")

# %%
recipes.head()
# Out:
#                                          name      id  contributor_id  \
# 0  arriba   baked winter squash mexican style  137739           47892
# 1            a bit different  breakfast pizza   31490           26278
# 2                   all in the kitchen  chili  112140          196586
# 3                          alouette  potatoes   59389           68585
# 4          amish  tomato ketchup  for canning   44061           41706
#
#     submitted                                               tags  \
# 0  16/09/2005  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  17/06/2002  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  25/02/2005  ['time-to-make', 'course', 'preparation', 'mai...
# 3  14/04/2003  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  25/10/2002  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %% [markdown]
# # Naloga 1
#
# Želimo narediti pizzo.
# Obdržati želimo vse vrstice, ki imajo v stolpcu `name` vrednost pizza.

# %%
recipes['name'].head(10)
# Out:
# 0    arriba   baked winter squash mexican style
# 1              a bit different  breakfast pizza
# 2                     all in the kitchen  chili
# 3                            alouette  potatoes
# 4            amish  tomato ketchup  for canning
# 5                       apple a day  milk shake
# 6                         aww  marinated olives
# 7                backyard style  barbecued ribs
# 8                      bananas 4 ice cream  pie
# 9                       beat this  banana bread
# Name: name, dtype: object

# %%
# Rešitev

#recipes[recipes['name'].str.match('pizza', na=False)]
recipes[recipes['name'].str.contains("pizza", na=False)].head()
# Out:
#                                  name      id  contributor_id   submitted  \
# 1    a bit different  breakfast pizza   31490           26278  17/06/2002
# 76              pizza  stuffed potato   52443            1533  28/01/2003
# 255           pizza pan  potato skins   60938           35635  24/04/2003
# 256                      pizza  steak  228491          474322  17/05/2007
# 307             5 minute bread  pizza  487173         2406227  19/09/2012
#
#                                                   tags  \
# 1    ['30-minutes-or-less', 'time-to-make', 'course...
# 76   ['30-minutes-or-less', 'time-to-make', 'course...
# 255  ['60-minutes-or-less', 'time-to-make', 'course...
# 256  ['30-minutes-or-less', 'time-to-make', 'course...
# 307  ['weeknight', '60-minutes-or-less', 'time-to-m...
#
#                                       nutrition  n_steps  \
# 1     [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 76    [183.3, 12.0, 9.0, 15.0, 21.0, 23.0, 6.0]        8
# 255  [503.9, 45.0, 9.0, 23.0, 37.0, 68.0, 13.0]       10
# 256  [215.1, 21.0, 15.0, 30.0, 16.0, 21.0, 4.0]       10
# 307   [276.0, 34.0, 8.0, 29.0, 27.0, 42.0, 1.0]       30
#
#                                                  steps  \
# 1    ['preheat oven to 425 degrees f', 'press dough...
# 76   ['preheat oven to 450 degrees', 'cut potato in...
# 255  ['preheat oven to 375f', 'cook the diced bacon...
# 256  ['combine flour , salt , & pepper', 'pound int...
# 307  ['1', 'cover the top of your pizza stone or , ...
#
#                                            description  \
# 1    this recipe calls for the crust to be prebaked...
# 76                                                 NaN
# 255  there's a pub we go to that makes their own fr...
# 256  this was a favorite of my children when they w...
# 307  my son recently showed me a recipe for artisan...
#
#                                            ingredients  n_ingredients
# 1    ['prepared pizza crust', 'sausage patty', 'egg...              6
# 76   ['baking potato', 'mozzarella cheese', 'tomato...              7
# 255  ['potatoes', 'bacon', 'cheddar cheese', 'green...              7
# 256  ['plain flour', 'salt', 'pepper', 'boneless ey...              9
# 307  ['extra virgin olive oil', 'black olives', 'wh...              8

# %% [markdown]
# # Naloga 2
#
# Želimo napraviti pico, ki vsebuje jajca in salamo.
# Obdržati želimo vse vrstice, ki imajo v stolpcu `ingredients` vrednosti **egg** in **sausage**.
#
# (Naj vas izgled ne zmoti. Stvari zgledajo, kot da so tipa `list` vendar jih lahko smatramo kot `string`)

# %%
our_ingredients = ["egg", "sausage"]

# %%
# Rešitev

recipes[recipes['ingredients'].str.contains(*our_ingredients, na=False)].head()
# Out:
#                                 name     id  contributor_id   submitted  \
# 1   a bit different  breakfast pizza  31490           26278  17/06/2002
# 9            beat this  banana bread  75452           15892  04/11/2003
# 11     better than sex  strawberries  42198           41531  03/10/2002
# 16                    chile rellenos  43026           52268  14/10/2002
# 22           crispy crunchy  chicken  83873          108291  13/02/2004
#
#                                                  tags  \
# 1   ['30-minutes-or-less', 'time-to-make', 'course...
# 9   ['weeknight', 'time-to-make', 'course', 'main-...
# 11  ['weeknight', 'time-to-make', 'course', 'main-...
# 16  ['60-minutes-or-less', 'time-to-make', 'course...
# 22  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                             nutrition  n_steps  \
# 1           [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 9   [2669.3, 160.0, 976.0, 107.0, 62.0, 310.0, 138.0]       12
# 11      [734.1, 66.0, 199.0, 10.0, 10.0, 117.0, 28.0]        8
# 16           [94.0, 10.0, 0.0, 11.0, 11.0, 21.0, 0.0]        9
# 22         [335.8, 11.0, 2.0, 24.0, 64.0, 10.0, 10.0]        8
#
#                                                 steps  \
# 1   ['preheat oven to 425 degrees f', 'press dough...
# 9   ['preheat oven to 350 degrees', 'butter two 9x...
# 11  ['crush vanilla wafers into fine crumbs and li...
# 16  ['drain green chiles', 'sprinkle cornstarch on...
# 22  ['combine soup , egg and seasoned salt in a bo...
#
#                                           description  \
# 1   this recipe calls for the crust to be prebaked...
# 9                                 from ann hodgman's
# 11  simple but sexy. this was in my local newspape...
# 16  a favorite from a local restaurant no longer i...
# 22  delicious, crunchy fried chicken. this recipe ...
#
#                                           ingredients  n_ingredients
# 1   ['prepared pizza crust', 'sausage patty', 'egg...              6
# 9   ['sugar', 'unsalted butter', 'bananas', 'eggs'...              9
# 11  ['vanilla wafers', 'butter', 'powdered sugar',...              7
# 16  ['egg roll wrap', 'whole green chilies', 'chee...              5
# 22  ['boneless skinless chicken breast halves', 'c...             10

# %% [markdown]
# # Naloga 3
#
# Želimo le pizze, ki jih je mogoče napraviti v 45min ali manj.
# Želimo obdržati vrstice, ki v stolpcu `tags` vsebujejo **45-minutes-or-less** ali katerokoli manjšo številčno vrednost.

# %%
s = recipes.loc[recipes['tags'].str.contains('30-minutes-or-less'), 'tags_2'] = 'quick_pizza'
s
# Out:
# 'quick_pizza'

# %%
recipes[(recipes['tags'].str.contains('30-minutes-or-less')) & (recipes['tags'].str.contains('weeknight'))]
# Out:
#                                       name      id  contributor_id  \
# 131                                5 tacos  500166         2549237
# 653            herman starter  sweet rolls  420409         1424434
# 711  ultimate  dark chocolate oreo truffle  468143         1926889
#
#       submitted                                               tags  \
# 131  13/05/2013  ['weeknight', '30-minutes-or-less', 'time-to-m...
# 653  14/04/2010  ['weeknight', '30-minutes-or-less', 'time-to-m...
# 711  13/11/2011  ['weeknight', '30-minutes-or-less', 'time-to-m...
#
#                                       nutrition  n_steps  \
# 131    [249.4, 26.0, 4.0, 6.0, 39.0, 39.0, 0.0]        5
# 653  [258.0, 18.0, 106.0, 8.0, 3.0, 19.0, 12.0]        7
# 711    [172.3, 18.0, 35.0, 5.0, 5.0, 29.0, 5.0]       10
#
#                                                  steps  \
# 131  ['cook meat', 'add taco seasoning', 'place mea...
# 653  ['preheat oven to 425 and grease a pie or roun...
# 711  ['set out 1 pkg philadelphia cream cheese', 'i...
#
#                                            description  \
# 131                         costs about $5.00 to make.
# 653  these cinnamon sweet rolls are made with the f...
# 711  only 3 ingredients!  this is my all-time favor...
#
#                                            ingredients  n_ingredients  \
# 131  ['ground beef', 'taco seasoning', 'taco shells...              9
# 653  ['herman starter', 'all-purpose flour', 'bakin...             10
# 711  ['oreo cookies', 'philadelphia cream cheese', ...              3
#
#           tags_2
# 131  quick_pizza
# 653  quick_pizza
# 711  quick_pizza

# %%
recipes.head()
# Out:
#                                          name      id  contributor_id  \
# 0  arriba   baked winter squash mexican style  137739           47892
# 1            a bit different  breakfast pizza   31490           26278
# 2                   all in the kitchen  chili  112140          196586
# 3                          alouette  potatoes   59389           68585
# 4          amish  tomato ketchup  for canning   44061           41706
#
#     submitted                                               tags  \
# 0  16/09/2005  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  17/06/2002  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  25/02/2005  ['time-to-make', 'course', 'preparation', 'mai...
# 3  14/04/2003  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  25/10/2002  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8
#
#         tags_2
# 0          NaN
# 1  quick_pizza
# 2          NaN
# 3          NaN
# 4          NaN

# %%
recipes[recipes.tags_2 == 'quick_pizza']
# Out:
#                                                   name      id  \
# 1                     a bit different  breakfast pizza   31490
# 23                          deep fried dessert thingys  107699
# 24                     easiest ever  hollandaise sauce   49262
# 33                            grilled  venison burgers   54100
# 37   i can t believe it s low fat  creamy potato salad   33165
# 38                        i can t believe it s spinach   38798
# 40          i stole the idea from mirj  sesame noodles   90921
# 44                       italian sandwich  pasta salad   33606
# 55            love is in the air  beef fondue   sauces   84797
# 56                        make it your way  shortcakes   35653
# 57                make that chicken dance  salsa pasta   32169
# 60                                       mexican pasta   60219
# 66                              my muffuletta sandwich   78655
# 73                                open sesame  noodles  107229
# 75                    pick me up  party chicken kabobs   42570
# 76                               pizza  stuffed potato   52443
# 77                  pour over anything  mushroom gravy   35595
# 102                            truth serum  margaritas   45859
# 103                                    turtle  squares   58651
# 110                               1 asian noodle salad   70099
# 120                             1 000 artichoke hearts   24514
# 129                      250 00 chocolate chip cookies  118843
# 130                                          300 icing  208179
# 131                                            5 tacos  500166
# 155                   better than a baked potato  soup  241445
# 175           cream   of pumpkin or squash soup  vegan  164526
# 183  don t bother with the canned stuff    sloppy joes  311991
# 185                                drunken  pork chops  242830
# 186                               egg  cellent noodles  336744
# 187                    even i like these  bran muffins   83542
# ..                                                 ...     ...
# 665                        my way of   steamed cabbage  202949
# 667              new  vanishing oatmeal raisin cookies  497150
# 670                                     not  meatballs  184214
# 673                      panera bread  black bean soup   49737
# 677  raw  angel hair zucchini  pasta  with fresh pesto  187601
# 683                               spicy  pasta fagioli  426696
# 685                       surprise   russian tea cakes  229979
# 692                                real   spanish rice  266021
# 699                                   minestrone salad  429248
# 703                            baked mozzarella sticks  218967
# 706                     low calorie  lemon chiffon pie  230686
# 707                               no cook summer pasta  470837
# 711              ultimate  dark chocolate oreo truffle  468143
# 718              tasty s    the power of flower7 salad  374703
# 737                    1 bowl 1 person mashed potatoes  236346
# 749                                   1 pan fudge cake   29935
# 754                                  1 potato 2 potato  374271
# 766                                     1 2 3 biscuits  146767
# 771                                   1 2 3 enchiladas  302498
# 773                   1 2 3 ground turkey mexican rice  378067
# 775                                 1 2 3 healthy soup  266081
# 778                                1 2 3 peach cobbler  320454
# 780                      1 2 3 rice and chili burritos  216873
# 788            1 dish caramel pecan coffee cake  round  256535
# 802                                       1 2 cup soup  172373
# 804                                   1 2 way brownies  240165
# 805                          1 3  pound squeeze burger  344373
# 807        10 calorie chocolate miracle noodle cookies  478546
# 811                                   10 grain muffins  351229
# 814                                     10 layer salad  459089
#
#      contributor_id   submitted  \
# 1             26278  17/06/2002
# 23           158966  05/01/2005
# 24            64428  19/12/2002
# 33            68357  15/02/2003
# 37            40493  04/07/2002
# 38             1533  29/08/2002
# 40            15851  10/05/2004
# 44            26278  08/07/2002
# 55             4470  23/02/2004
# 56             6164  29/07/2002
# 57            27678  25/06/2002
# 60            76846  18/04/2003
# 66            12875  12/12/2003
# 73           173674  30/12/2004
# 75             6164  07/10/2002
# 76             1533  28/01/2003
# 77             6164  29/07/2002
# 102           59756  13/11/2002
# 103           35635  07/04/2003
# 110           75379  02/09/2003
# 120           23302  08/04/2002
# 129          145599  24/04/2005
# 130          189797  30/01/2007
# 131         2549237  13/05/2013
# 155          533770  19/07/2007
# 175           47892  16/04/2006
# 183          435663  04/07/2008
# 185          305531  27/07/2007
# 186          719313  12/11/2008
# 187           71479  10/02/2004
# ..              ...         ...
# 665           29782  02/01/2007
# 667         2651788  10/03/2013
# 670          347727  31/08/2006
# 673           18391  03/01/2003
# 677          247958  26/09/2006
# 683         1010338  21/05/2010
# 685          330545  24/05/2007
# 692          522036  15/11/2007
# 699          674022  09/06/2010
# 703          360500  26/03/2007
# 706          444200  28/05/2007
# 707         2122596  30/12/2011
# 711         1926889  13/11/2011
# 718           47892  27/05/2009
# 737          462336  21/06/2007
# 749           22015  31/05/2002
# 754          452940  26/05/2009
# 766           78884  29/11/2005
# 771          454149  06/05/2008
# 773         1299206  22/06/2009
# 775          651132  16/11/2007
# 778          214039  19/08/2008
# 780          464327  14/03/2007
# 788           57042  01/10/2007
# 802          112864  11/06/2006
# 804          464327  12/07/2007
# 805           23119  20/12/2008
# 807         2247203  26/04/2012
# 811           17803  22/01/2009
# 814         1464153  20/06/2011
#
#                                                   tags  \
# 1    ['30-minutes-or-less', 'time-to-make', 'course...
# 23   ['30-minutes-or-less', 'time-to-make', 'course...
# 24   ['30-minutes-or-less', 'time-to-make', 'course...
# 33   ['30-minutes-or-less', 'time-to-make', 'course...
# 37   ['30-minutes-or-less', 'time-to-make', 'course...
# 38   ['30-minutes-or-less', 'time-to-make', 'course...
# 40   ['30-minutes-or-less', 'time-to-make', 'course...
# 44   ['30-minutes-or-less', 'time-to-make', 'course...
# 55   ['30-minutes-or-less', 'time-to-make', 'course...
# 56   ['30-minutes-or-less', 'time-to-make', 'course...
# 57   ['30-minutes-or-less', 'time-to-make', 'course...
# 60   ['30-minutes-or-less', 'time-to-make', 'course...
# 66   ['30-minutes-or-less', 'time-to-make', 'course...
# 73   ['30-minutes-or-less', 'time-to-make', 'course...
# 75   ['30-minutes-or-less', 'time-to-make', 'course...
# 76   ['30-minutes-or-less', 'time-to-make', 'course...
# 77   ['30-minutes-or-less', 'time-to-make', 'course...
# 102  ['30-minutes-or-less', 'time-to-make', 'course...
# 103  ['30-minutes-or-less', 'time-to-make', 'course...
# 110  ['30-minutes-or-less', 'time-to-make', 'course...
# 120  ['30-minutes-or-less', 'time-to-make', 'course...
# 129  ['30-minutes-or-less', 'time-to-make', 'course...
# 130  ['30-minutes-or-less', 'time-to-make', 'course...
# 131  ['weeknight', '30-minutes-or-less', 'time-to-m...
# 155  ['30-minutes-or-less', 'time-to-make', 'course...
# 175  ['30-minutes-or-less', 'time-to-make', 'course...
# 183  ['30-minutes-or-less', 'time-to-make', 'course...
# 185  ['30-minutes-or-less', 'time-to-make', 'course...
# 186  ['30-minutes-or-less', 'time-to-make', 'course...
# 187  ['30-minutes-or-less', 'time-to-make', 'course...
# ..                                                 ...
# 665  ['30-minutes-or-less', 'time-to-make', 'main-i...
# 667  ['30-minutes-or-less', 'time-to-make', 'course...
# 670  ['30-minutes-or-less', 'time-to-make', 'course...
# 673  ['30-minutes-or-less', 'time-to-make', 'course...
# 677  ['lactose', '30-minutes-or-less', 'time-to-mak...
# 683  ['30-minutes-or-less', 'time-to-make', 'prepar...
# 685  ['30-minutes-or-less', 'time-to-make', 'course...
# 692  ['30-minutes-or-less', 'time-to-make', 'course...
# 699  ['30-minutes-or-less', 'time-to-make', 'course...
# 703  ['30-minutes-or-less', 'time-to-make', 'course...
# 706  ['30-minutes-or-less', 'time-to-make', 'course...
# 707  ['30-minutes-or-less', 'time-to-make', 'course...
# 711  ['weeknight', '30-minutes-or-less', 'time-to-m...
# 718  ['30-minutes-or-less', 'time-to-make', 'course...
# 737  ['30-minutes-or-less', 'time-to-make', 'course...
# 749  ['30-minutes-or-less', 'time-to-make', 'course...
# 754  ['30-minutes-or-less', 'time-to-make', 'course...
# 766  ['30-minutes-or-less', 'time-to-make', 'course...
# 771  ['30-minutes-or-less', 'time-to-make', 'course...
# 773  ['30-minutes-or-less', 'time-to-make', 'course...
# 775  ['30-minutes-or-less', 'time-to-make', 'course...
# 778  ['30-minutes-or-less', 'time-to-make', 'course...
# 780  ['30-minutes-or-less', 'time-to-make', 'course...
# 788  ['30-minutes-or-less', 'time-to-make', 'course...
# 802  ['30-minutes-or-less', 'time-to-make', 'course...
# 804  ['30-minutes-or-less', 'time-to-make', 'course...
# 805  ['30-minutes-or-less', 'time-to-make', 'course...
# 807  ['30-minutes-or-less', 'time-to-make', 'course...
# 811  ['30-minutes-or-less', 'time-to-make', 'course...
# 814  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                              nutrition  n_steps  \
# 1            [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 23     [1663.3, 221.0, 168.0, 66.0, 19.0, 158.0, 29.0]       20
# 24        [1290.4, 213.0, 4.0, 53.0, 22.0, 417.0, 1.0]        7
# 33          [190.9, 10.0, 10.0, 10.0, 45.0, 15.0, 2.0]       13
# 37            [152.5, 2.0, 20.0, 13.0, 7.0, 3.0, 10.0]       12
# 38                [53.8, 5.0, 2.0, 3.0, 3.0, 3.0, 1.0]        5
# 40        [783.4, 46.0, 107.0, 56.0, 36.0, 21.0, 37.0]        8
# 44         [279.2, 14.0, 12.0, 22.0, 23.0, 11.0, 12.0]        6
# 55    [1615.2, 154.0, 323.0, 74.0, 182.0, 193.0, 30.0]        4
# 56            [175.2, 11.0, 15.0, 8.0, 7.0, 21.0, 7.0]       11
# 57          [255.2, 18.0, 39.0, 18.0, 39.0, 13.0, 6.0]        7
# 60         [325.3, 10.0, 11.0, 39.0, 26.0, 17.0, 17.0]        5
# 66            [181.1, 26.0, 6.0, 17.0, 2.0, 11.0, 2.0]        3
# 73         [617.5, 34.0, 13.0, 20.0, 56.0, 18.0, 24.0]        8
# 75           [213.6, 24.0, 0.0, 26.0, 31.0, 16.0, 0.0]        5
# 76           [183.3, 12.0, 9.0, 15.0, 21.0, 23.0, 6.0]        8
# 77               [33.1, 0.0, 11.0, 0.0, 2.0, 0.0, 2.0]        6
# 102              [72.0, 0.0, 61.0, 0.0, 0.0, 0.0, 6.0]        3
# 103           [172.4, 16.0, 51.0, 1.0, 2.0, 26.0, 6.0]       15
# 110           [231.1, 7.0, 21.0, 32.0, 8.0, 3.0, 14.0]        7
# 120        [422.5, 25.0, 20.0, 46.0, 34.0, 43.0, 19.0]        6
# 129  [5286.9, 427.0, 1630.0, 159.0, 163.0, 656.0, 2...        3
# 130         [339.0, 37.0, 100.0, 7.0, 3.0, 76.0, 10.0]        9
# 131           [249.4, 26.0, 4.0, 6.0, 39.0, 39.0, 0.0]        5
# 155        [607.1, 40.0, 40.0, 65.0, 45.0, 81.0, 23.0]       13
# 175              [89.3, 0.0, 35.0, 0.0, 4.0, 0.0, 7.0]        9
# 183         [257.4, 17.0, 47.0, 23.0, 47.0, 23.0, 4.0]        7
# 185           [300.5, 27.0, 6.0, 6.0, 47.0, 27.0, 1.0]       12
# 186          [308.0, 29.0, 6.0, 30.0, 32.0, 36.0, 5.0]       11
# 187  [2488.6, 199.0, 775.0, 133.0, 87.0, 116.0, 109.0]       13
# ..                                                 ...      ...
# 665          [146.7, 16.0, 24.0, 14.0, 5.0, 20.0, 3.0]        6
# 667           [193.2, 12.0, 58.0, 5.0, 5.0, 22.0, 9.0]       15
# 670              [95.6, 6.0, 3.0, 6.0, 11.0, 8.0, 3.0]        4
# 673           [241.4, 1.0, 9.0, 32.0, 29.0, 1.0, 14.0]        9
# 677         [374.7, 57.0, 22.0, 31.0, 10.0, 21.0, 3.0]        7
# 683          [216.2, 3.0, 18.0, 21.0, 23.0, 2.0, 12.0]        9
# 685            [101.4, 9.0, 13.0, 2.0, 2.0, 17.0, 3.0]        8
# 692           [373.5, 1.0, 7.0, 25.0, 14.0, 1.0, 27.0]        6
# 699         [219.2, 16.0, 11.0, 15.0, 14.0, 13.0, 7.0]        9
# 703           [162.6, 9.0, 4.0, 15.0, 17.0, 18.0, 5.0]       16
# 706            [136.9, 5.0, 81.0, 0.0, 2.0, 16.0, 8.0]        8
# 707        [559.2, 40.0, 25.0, 11.0, 37.0, 36.0, 20.0]       17
# 711           [172.3, 18.0, 35.0, 5.0, 5.0, 29.0, 5.0]       10
# 718               [28.2, 0.0, 8.0, 1.0, 3.0, 0.0, 1.0]       11
# 737         [445.7, 42.0, 6.0, 11.0, 17.0, 87.0, 14.0]        7
# 749        [369.6, 26.0, 120.0, 15.0, 6.0, 10.0, 17.0]        5
# 754          [173.9, 15.0, 9.0, 15.0, 10.0, 28.0, 5.0]       11
# 766         [415.7, 31.0, 0.0, 36.0, 15.0, 18.0, 16.0]        5
# 771          [195.9, 14.0, 5.0, 14.0, 26.0, 22.0, 4.0]       10
# 773             [214.9, 9.0, 0.0, 8.0, 41.0, 8.0, 6.0]        5
# 775        [637.0, 22.0, 92.0, 32.0, 76.0, 14.0, 31.0]        4
# 778           [225.0, 1.0, 128.0, 2.0, 9.0, 0.0, 17.0]       14
# 780         [302.8, 14.0, 7.0, 30.0, 19.0, 16.0, 15.0]        7
# 788         [330.2, 17.0, 89.0, 8.0, 12.0, 20.0, 17.0]       10
# 802        [313.8, 20.0, 22.0, 49.0, 36.0, 11.0, 10.0]        8
# 804              [91.4, 5.0, 40.0, 1.0, 2.0, 4.0, 4.0]        5
# 805      [975.7, 112.0, 21.0, 43.0, 134.0, 204.0, 3.0]       10
# 807               [19.1, 0.0, 8.0, 3.0, 3.0, 1.0, 1.0]       26
# 811           [131.9, 9.0, 38.0, 16.0, 5.0, 17.0, 5.0]        7
# 814         [229.3, 24.0, 20.0, 23.0, 17.0, 20.0, 4.0]       13
#
#                                                  steps  \
# 1    ['preheat oven to 425 degrees f', 'press dough...
# 23   ['in a large bowl , mix flour , granulated sug...
# 24   ['cut the butter into several pieces and bring...
# 33   ['in bowl , mix dry ingredients', 'add venison...
# 37   ['cut potatoes into 1 / 2" pieces', 'place in ...
# 38   ['combine all ingredients in a large bowl and ...
# 40   ['in a large pot , cook your angel hair pasta ...
# 44   ['cook pasta and set aside', 'place onions , d...
# 55   ['honey mustard sauce: whisk all the ingredien...
# 56   ['pre-heat the oven to 450', 'sift together th...
# 57   ['heat oil in a frying pan and saut the onions...
# 60   ['boil pasta as directed on package', 'drain a...
# 66   ['mix everything in food processor', 'chop fin...
# 73   ['cook pasta in salted water until al dente', ...
# 75   ['combine all ingredients in a non-reactive bo...
# 76   ['preheat oven to 450 degrees', 'cut potato in...
# 77   ['in a small saucepan , saut onion and mushroo...
# 102  ['mix limeade , lime juice , tequila and tripl...
# 103  ['preheat oven to 350 degrees f', 'spray a 13 ...
# 110  ['bring a large pot of water to boil', 'add ri...
# 120  ['squeeze as much liquid as possible out of th...
# 129  ['mix all ingredients together just until blen...
# 130  ['this first part is best made ahead to allow ...
# 131  ['cook meat', 'add taco seasoning', 'place mea...
# 155  ['peel potatoes and cut into large chunks', 'p...
# 175  ['place all ingredients except for banana , ap...
# 183  ['brown beef til no longer pink', 'strain away...
# 185  ['season pork with salt and pepper', 'heat oil...
# 186  ['spray oven-proof skillet with cooking spray ...
# 187  ['preheat oven to 375c', 'beat eggs , add suga...
# ..                                                 ...
# 665  ['in a large frying pan on medium heat , spray...
# 667  ['heat oven to 350f', 'in a large bowl , beat ...
# 670  ['whisk eggs and milk , add other ingredients ...
# 673  ['in a pot , combine the first six ingredients...
# 677  ['using a vegetable peeler or a spiral vegetab...
# 683  ['heat oil in saucepan over medium-high heat',...
# 685  ['heat oven to 400', "mix thoroughly butter , ...
# 692  ['using a teflon pan- place olive oil in the p...
# 699  ['cook pasta to desired doneness as directed o...
# 703  ['remove cheese from packages', 'cut each chee...
# 706  ['mix cornstarch with 1 / 4 cup of the pineapp...
# 707  ['start by toasting your pine nuts', 'use a dr...
# 711  ['set out 1 pkg philadelphia cream cheese', 'i...
# 718  ['of course , how you arrange the produce and ...
# 737  ['place the potato on a pot and fill it with w...
# 749  ['preheat oven to 350 degrees', 'in an ungreas...
# 754  ['preheat oven to 400 degrees fahrenheit', 'sp...
# 766  ['mix the first 3 ingredients together in a bo...
# 771  ['preheat oven to 350f degrees', 'warm the tor...
# 773  ['cook rice according to package directions', ...
# 775  ['cook the soy beans as directed on package in...
# 778  ['combine cinnamon , vanilla , cornstarch , pe...
# 780  ['heat chili in saucepan', 'once heated , add ...
# 788  ['mix batter ingredients in a pre-sprayed 9-1 ...
# 802  ['heat oil in small dutch oven', 'saute vegeta...
# 804  ['over low heat , in small saucepan , melt the...
# 805  ["divide the meat into 3 evenly sized burgers ...
# 807  ['made-1 dozen teaspoon sized cookies', '10 ca...
# 811  ['mix 10 grain cereal and milk', 'allow to sta...
# 814  ['in a large bowl , layer each of the followin...
#
#                                            description  \
# 1    this recipe calls for the crust to be prebaked...
# 23   my mother used to make this for us as a specia...
# 24   the secret to this easy hollandaise sauce is i...
# 33                delicious venison burgers with that
# 37   the name says it all. you have to try it to be...
# 38             these were so go, it surprised even me.
# 40   i love mirj's funky chicken with sesame noodle...
# 44   this is a fun salad that uses the same ingredi...
# 55   i think a fondue is a very romantic casual din...
# 56   top with freshly sliced strawberries and whipp...
# 57   i made this up the other night after i started...
# 60   made this as a side dish for mexican meatballs...
# 66                    watched a documentary about the
# 73   this is a very versatile and widely enjoyed pa...
# 75        serve as an appetizer or party pick-up food.
# 76                                                 NaN
# 77   the name says it all...absolute must for all t...
# 102  you'll know why i call it truth serum after yo...
# 103              for lovers of pecans and chocolate...
# 110  i am addicted to this! and it's so easy to mak...
# 120  by chef anthony fielding at poncho's wreck res...
# 129        these are great! the perfect name for them!
# 130  don't know where this recipe originated, just ...
# 131                         costs about $5.00 to make.
# 155  this is my own concoction. i got my mom's regu...
# 175  the creaminess comes from cashew butter (and b...
# 183  simple weeknight meal that my family really li...
# 185          a simple stove-top dish from bon appetit.
# 186               made for dining on a dollar contest.
# 187  i got this recipe from my mom in law. i am not...
# ..                                                 ...
# 665  i remember when i was growing up watching my g...
# 667  from the quaker carton (current as of 2012).\r...
# 670  meatball substitute for vegetarians. i wrote t...
# 673  this is my own version of panera bread's black...
# 677  this is a raw recipe from natural health magaz...
# 683  saw this in a 2009 issue of family circle.  i ...
# 685  a sweet surprise awaits those who bite into th...
# 692  i have been making this for 40 years and share...
# 699  perfect for cookouts, grilling, potlucks and m...
# 703  tasty & easy finger food for anytime of the day!!
# 706  yummy delicious and healthy for those of you w...
# 707  i found this recipe in a 2000 in style magazin...
# 711  only 3 ingredients!  this is my all-time favor...
# 718                                             #NAME?
# 737  ever feel like having mashed potatoes but you ...
# 749  this is my favorite chocolate cake. no fuss, n...
# 754  we created this recipe for when the family is ...
# 766  i can not wait to try this recipe. i found it ...
# 771  this is the best recipe for quick enchiladas t...
# 773  i found this years ago in a magazine and have ...
# 775  this soup is super healthy and super good at c...
# 778                                      heart healthy
# 780  these are the best to make when you want to be...
# 788  i have not tried this recipe. i got it from fl...
# 802  i make soup like this based on what's freshest...
# 804  these brownies don't contain as much chocolate...
# 805  adapted from a recipe courtesy of squeeze inn....
# 807  a moist chocolate cookie that reminds me of a ...
# 811  i am hooked on whole grain hot cereals.  the o...
# 814  this recipe was given to me from my girlfiend'...
#
#                                            ingredients  n_ingredients  \
# 1    ['prepared pizza crust', 'sausage patty', 'egg...              6
# 23   ['all-purpose flour', 'granulated sugar', 'bak...             13
# 24   ['butter', 'lemon, juice of', 'salt', 'white p...              5
# 33   ['ground venison', 'egg substitute', 'non-fat ...             10
# 37   ['red potatoes', 'green onion', 'diced pimento...             13
# 38   ['frozen chopped spinach', 'eggs', 'garlic pow...              8
# 40   ['angel hair pasta', 'toasted sesame oil', 'so...              8
# 44   ['tri-color spiral pasta', 'dill pickles', 'ri...             16
# 55   ['beef steaks', 'vegetable oil', 'spicy mustar...             12
# 56   ['flour', 'salt', 'baking powder', 'sugar', 'b...              7
# 57   ['tomatoes', 'garlic', 'onion', 'button mushro...             15
# 60   ['fettuccine pasta', 'cheddar cheese soup', 'm...              6
# 66   ['ciabatta', 'provolone cheese', 'genoa salami...             17
# 73   ['vermicelli', 'rice vinegar', 'reduced sodium...             12
# 75   ['boneless chicken breast', 'garlic', 'salt', ...             10
# 76   ['baking potato', 'mozzarella cheese', 'tomato...              7
# 77   ['onion', 'mushroom pieces', 'sodium-free vege...              8
# 102  ['limeade', 'lime juice', 'tequila', 'triple s...              6
# 103  ['flour', 'brown sugar', 'butter', 'pecans', '...              5
# 110  ['rice noodles', 'carrot', 'english cucumber',...             13
# 120  ['artichoke hearts', 'egg', 'unseasoned breadc...              6
# 129  ['butter', 'white sugar', 'brown sugar', 'eggs...             13
# 130  ['milk', 'flour', 'butter', 'granulated sugar'...              5
# 131  ['ground beef', 'taco seasoning', 'taco shells...              9
# 155  ['red potatoes', 'onion', 'celery', 'chicken b...             12
# 175  ['pumpkin puree', 'vegetable broth', 'small re...             14
# 183  ['lean ground beef', 'steak seasoning', 'onion...             12
# 185  ['pork chops', 'olive oil', 'onion', 'fennel s...              8
# 186  ['ramen noodles', 'eggs', 'red bell pepper', '...              9
# 187  ['eggs', 'brown sugar', 'oil', 'milk', 'molass...             13
# ..                                                 ...            ...
# 665  ['head of cabbage', 'onion', 'fresh mushrooms'...             11
# 667  ['butter', 'brown sugar', 'granulated sugar', ...             11
# 670  ['ground meat substitute', 'minced garlic clov...             12
# 673  ['onion', 'garlic cloves', 'celery ribs', 'red...             11
# 677  ['zucchini', 'green tomato', 'extra virgin oli...              9
# 683  ['olive oil', 'garlic cloves', 'tomato sauce',...             13
# 685  ['butter', "confectioners' sugar", 'all-purpos...              7
# 692  ['rice', 'water', 'beef bouillon', 'salt', 'ch...             10
# 699  ['bow tie pasta', 'red kidney beans', 'peppero...              9
# 703  ['mozzarella string cheese', 'all-purpose flou...             10
# 706  ['cornstarch', 'unsweetened pineapple juice', ...              6
# 707  ['basil', 'garlic cloves', 'balsamic vinegar',...             11
# 711  ['oreo cookies', 'philadelphia cream cheese', ...              3
# 718  ['baby spinach leaves', 'green onions', 'bell ...              9
# 737     ['potato', 'butter', 'milk', 'salt', 'pepper']              5
# 749  ['sugar', 'cocoa', 'baking soda', 'flour', 'sa...              9
# 754  ['mashed potatoes', 'sour cream', 'cheddar che...              9
# 766  ['salt', 'flour', 'baking powder', 'oil', 'milk']              5
# 771  ['chili without beans', 'corn tortillas', 'dic...              6
# 773  ['mexican rice', 'black beans', 'mexicorn', 'l...              4
# 775  ['soybeans', 'chicken stock', 'broccoli', 'red...              6
# 778  ['cinnamon', 'vanilla extract', 'cornstarch', ...             14
# 780  ['chili with beans', 'instant rice', 'water', ...              6
# 788  ['cooking spray', 'all-purpose flour', 'fast r...             11
# 802  ['olive oil', 'onion', 'chicken broth', 'fresh...             15
# 804  ['margarine', 'shortening', 'sugar', 'chocolat...              9
# 805  ['ground beef', "lawry's seasoned salt", 'mild...             10
# 807  ['shirataki noodles', 'egg whites', 'dutch-pro...              6
# 811  ['egg', 'sugar', 'butter', 'unbleached white f...              9
# 814  ['head iceberg lettuce', 'frozen peas', 'red o...             10
#
#           tags_2
# 1    quick_pizza
# 23   quick_pizza
# 24   quick_pizza
# 33   quick_pizza
# 37   quick_pizza
# 38   quick_pizza
# 40   quick_pizza
# 44   quick_pizza
# 55   quick_pizza
# 56   quick_pizza
# 57   quick_pizza
# 60   quick_pizza
# 66   quick_pizza
# 73   quick_pizza
# 75   quick_pizza
# 76   quick_pizza
# 77   quick_pizza
# 102  quick_pizza
# 103  quick_pizza
# 110  quick_pizza
# 120  quick_pizza
# 129  quick_pizza
# 130  quick_pizza
# 131  quick_pizza
# 155  quick_pizza
# 175  quick_pizza
# 183  quick_pizza
# 185  quick_pizza
# 186  quick_pizza
# 187  quick_pizza
# ..           ...
# 665  quick_pizza
# 667  quick_pizza
# 670  quick_pizza
# 673  quick_pizza
# 677  quick_pizza
# 683  quick_pizza
# 685  quick_pizza
# 692  quick_pizza
# 699  quick_pizza
# 703  quick_pizza
# 706  quick_pizza
# 707  quick_pizza
# 711  quick_pizza
# 718  quick_pizza
# 737  quick_pizza
# 749  quick_pizza
# 754  quick_pizza
# 766  quick_pizza
# 771  quick_pizza
# 773  quick_pizza
# 775  quick_pizza
# 778  quick_pizza
# 780  quick_pizza
# 788  quick_pizza
# 802  quick_pizza
# 804  quick_pizza
# 805  quick_pizza
# 807  quick_pizza
# 811  quick_pizza
# 814  quick_pizza
#
# [159 rows x 12 columns]

# %% [markdown]
# # Naloga 4
#
# Sedaj nas zanima na koliko stopinj moramo razgreti pečico.
# Dodati želimo stolpec **preheating** v katerega shranimo na koliko stopinj je potrebno segreti pečico. Ta podatek najdemo v stolpcu `steps`.
# (Če vrednosti ni, lahko pustimo NaN).

# %%
s = recipes.loc[recipes['steps'].str.contains('heat'), 'preheating'] = 'degrees'
recipes.head()
# Out:
#                                          name      id  contributor_id  \
# 0  arriba   baked winter squash mexican style  137739           47892
# 1            a bit different  breakfast pizza   31490           26278
# 2                   all in the kitchen  chili  112140          196586
# 3                          alouette  potatoes   59389           68585
# 4          amish  tomato ketchup  for canning   44061           41706
#
#     submitted                                               tags  \
# 0  16/09/2005  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  17/06/2002  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  25/02/2005  ['time-to-make', 'course', 'preparation', 'mai...
# 3  14/04/2003  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  25/10/2002  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8
#
#         tags_2 preheating
# 0          NaN        NaN
# 1  quick_pizza    degrees
# 2          NaN        NaN
# 3          NaN    degrees
# 4          NaN        NaN
